# %% [markdown]
# ### Advantage of Seaborn
# - Easy to Use
# - Works well with pandas
# - Built on top Matplotlib
#
# ### Example
# - Scatter plot
# - Countplot
#
# ### Works well with pandas
# - Example using dataframe
# - Adding Third Variable
#     - Example WIth Scatter plot
#
#
# ### Comparison Quantative Variable
# - relplot -> scatter plot, line plot
# - Custom Scatter plot -> size, style, alpha, palette
# - Custom Lineplot -> hue, style, marker, shaded
#
#
# ### comparison visualization
# - count plots, bar plot, box plot -> category -> catplot
# - count -> order,
# - bar -> ci
# - box ->

# %% [markdown]
# Numeric - Quantitaiv
# Categori - Qualitativ

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot?

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', 
                hue='species')
plt.show()

# %%
species_color = ['black', 'red', 'yellow']
sns.countplot(data=iris, x='species', palette=species_color)
plt.show()

# %%
sns.relplot(data=iris, x='sepal_length', y='sepal_width', 
            kind='scatter', col='species')
plt.show()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.relplot(data=titanic, x='fare', y='age', 
            kind='scatter', col='class', row='sex')
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data=tips, x='smoker', hue='size')
plt.show()

# %%
sns.relplot(data=tips, x='total_bill', y='tip', 
            kind='scatter', style='day', hue='time')
plt.show()

# %%
flight
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
flight.year.unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960], dtype=int64)

# %%
sns.relplot(data=flight, x='year', y='passengers', 
            kind='line', alpha=0.4, ci='sd')
plt.show()

# %%
sns.relplot(data=flight, x='year', y='passengers', 
            kind='line', hue='month')
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='time', data=tips, kind='count', col='smoker')

# %%
sns.catplot(x='time', y='total_bill', data=tips, kind='box')
plt.show()

# %%
sns.catplot?

# %%
g = sns.catplot(x='time', y='total_bill', data=tips, kind='box')

# %%
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
g1 = sns.countplot(data=iris, x='species', palette=species_color)

# %%
type(g1)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
catplot, relplot -> facetgrid
countplot, scatter -> AxesSubplot

# %%
g = sns.catplot(x='time', y='total_bill', data=tips, kind='box',
               col='time')
g.fig.suptitle('Title', y=1.1)
g.set_titles('ini subplot {col_name}')
g.set(xlabel='X Label', ylabel='Y label')
plt.show()

# %%
g.axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002053EF8ACC8>,
# ...
#       dtype=object)

# %%
g1 = sns.countplot(data=iris, x='species', palette=species_color)
g1.set_title('Test')
g1.set_xlabel('X Label')
# Out:
# Text(0.5, 0, 'X Label')
