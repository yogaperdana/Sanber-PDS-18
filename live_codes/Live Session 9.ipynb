# %% [markdown]
# - GroupBy
#     - Split - Apply - Combine
#     - Multi-level groupby
#     - Aggregation ->
#         - Multiple Aggregation
#         - Custom aggregation
#         - Aggregation with dictionary
#     - Transformation
#     - Filtering
#     - Apply

# %%
import seaborn

# %%
df = seaborn.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.groupby('model_year')[['weight']].mean()
# Out:
#                  weight
# model_year
# 70          3372.793103
# 71          2995.428571
# 72          3237.714286
# 73          3419.025000
# 74          2877.925926
# 75          3176.800000
# 76          3078.735294
# 77          2997.357143
# 78          2861.805556
# 79          3055.344828
# 80          2436.655172
# 81          2522.931034
# 82          2453.548387

# %%
for (year, group) in df.groupby('model_year'):
    print("Year : {}".format(year))
    print(group)
# Out:
# Year : 70
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 1   15.0          8         350.0       165.0    3693          11.5
# 2   18.0          8         318.0       150.0    3436          11.0
# 3   16.0          8         304.0       150.0    3433          12.0
# 4   17.0          8         302.0       140.0    3449          10.5
# 5   15.0          8         429.0       198.0    4341          10.0
# 6   14.0          8         454.0       220.0    4354           9.0
# 7   14.0          8         440.0       215.0    4312           8.5
# 8   14.0          8         455.0       225.0    4425          10.0
# 9   15.0          8         390.0       190.0    3850           8.5
# 10  15.0          8         383.0       170.0    3563          10.0
# 11  14.0          8         340.0       160.0    3609           8.0
# 12  15.0          8         400.0       150.0    3761           9.5
# ...

# %%
def range_value(group):
    return group.max() - group.min()

# %%
df.groupby('model_year')[['weight', 'acceleration']].aggregate({'weight':range_value, 'acceleration':'mean'})
# Out:
#             weight  acceleration
# model_year
# 70            2897     12.948276
# 71            3527     15.142857
# 72            2533     15.125000
# 73            3130     14.312500
# 74            3050     16.203704
# 75            2873     16.050000
# 76            2585     15.941176
# 77            2510     15.435714
# 78            2280     15.805556
# 79            2445     15.813793
# 80            1546     16.934483
# 81            1970     16.306897
# 82            1070     16.638710

# %%
import random

df_2 = pd.DataFrame({
    'key' : ['A', 'B', 'C', 'A', 'B', 'C'],
    'data1' : range(6),
    'data2' : random.choices(range(10), k=6)
})

# %%
df_2
# Out:
#   key  data1  data2
# 0   A      0      8
# 1   B      1      8
# 2   C      2      8
# 3   A      3      3
# 4   B      4      2
# 5   C      5      4

# %%
def some_func(x):
    return x-x.mean()

# %%
df_2.groupby('key').transform(some_func)
# Out:
#    data1  data2
# 0   -1.5    2.5
# 1   -1.5    3.0
# 2   -1.5    2.0
# 3    1.5   -2.5
# 4    1.5   -3.0
# 5    1.5   -2.0

# %%
df_2.groupby('key').mean()
# Out:
#      data1  data2
# key
# A      1.5    5.5
# B      2.5    5.0
# C      3.5    6.0

# %%
def filter_func(x):
    return x['data1'].mean() > 2

# %%
df_2.groupby('key').filter(filter_func)
# Out:
#   key  data1  data2
# 1   B      1      8
# 2   C      2      8
# 4   B      4      2
# 5   C      5      4

# %%
some_func = lambda x, y : x+y

# %%
some_func
# Out:
# <function __main__.<lambda>(x, y)>

# %%
some_func(5, 2)
# Out:
# 7

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
splitting = df.groupby('model_year')[['acceleration', 'name']]

# %%
data = {year:[group[group['name'].str.contains('chevrolet')].mean()['acceleration']]
        for (year, group) in splitting}

# %%
data
# Out:
# {70: [10.166666666666666],
#  71: [15.5],
#  72: [15.166666666666666],
#  73: [14.916666666666666],
#  74: [17.0],
#  75: [14.5],
#  76: [17.950000000000003],
#  77: [14.325],
#  78: [15.966666666666667],
#  79: [13.9],
#  80: [16.0],
#  81: [12.6],
#  82: [18.375]}

# %%
df3 = pd.DataFrame(data)

# %%
df3.index = ['rata2']

# %%
df3
# Out:
#               70    71         72         73    74    75     76      77  \
# rata2  10.166667  15.5  15.166667  14.916667  17.0  14.5  17.95  14.325
#
#               78    79    80    81      82
# rata2  15.966667  13.9  16.0  12.6  18.375

# %%
for (year, group) in splitting :
    rata2 = group[group['name'].str.contains('chevrolet')].mean()['acceleration']
    print('''Rata - Rata akselerasi untuk tahun {} 
            dan untuk setiap mobil yang memiliki nama chevrolet 
            adalah {}\n'''.format(year, rata2))
    data = {year : }
# Out:
# Rata - Rata akselerasi untuk tahun 70
#             dan untuk setiap mobil yang memiliki nama chevrolet
#             adalah 10.166666666666666
#
# Rata - Rata akselerasi untuk tahun 71
#             dan untuk setiap mobil yang memiliki nama chevrolet
#             adalah 15.5
#
# Rata - Rata akselerasi untuk tahun 72
#             dan untuk setiap mobil yang memiliki nama chevrolet
#             adalah 15.166666666666666
#
# Rata - Rata akselerasi untuk tahun 73
#             dan untuk setiap mobil yang memiliki nama chevrolet
#             adalah 14.916666666666666
#
# Rata - Rata akselerasi untuk tahun 74
#             dan untuk setiap mobil yang memiliki nama chevrolet
#             adalah 17.0
#
# Rata - Rata akselerasi untuk tahun 75
#             dan untuk setiap mobil yang memiliki nama chevrolet
#             adalah 14.5
#
# Rata - Rata akselerasi untuk tahun 76
#             dan untuk setiap mobil yang memiliki nama chevrolet
#             adalah 17.950000000000003
#
# ...

# %%
import re

# %%
filter_cond = df['name'].str.contains('chevrolet') | df['name'].str.contains('ford')

# %%
df[filter_cond]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ..    ...        ...           ...         ...     ...           ...
# 373  24.0          4         140.0        92.0    2865          16.4
# 389  22.0          6         232.0       112.0    2835          14.7
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 396  28.0          4         120.0        79.0    2625          18.6
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...
