# %% [markdown]
# - Multiple subplot with plt.axes
# - Multiple subplot with fig.add_axes
# - Multiple Plot with plt.subplot
# - Adjust jarak antara subplot
# - Multiple Plot with plt.subplots
# - GridSpec

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
ax = plt.axes()
ax2 = plt.axes((0.65, 0.65, 0.2, 0.2))

# %%
import numpy as np

x = np.arange(10)
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])
ax1.plot(x, np.cos(x))
ax2.plot(x, np.sin(x))

# %%
plt.subplot(1, 2, 1)
plt.text(0.5, 0.5, str((1, 2, 1)), fontsize=18, ha='center')
plt.subplot(1, 2, 2)
plt.subplot(1, 2, 2)
plt.subplot(1, 2, 2)
plt.subplot(1, 2, 2)
plt.subplot(1, 2, 2)

plt.text(0.5, 0.5, str((1, 2, 2)), fontsize=18, ha='center')
# Out:
# Text(0.5, 0.5, '(1, 2, 2)')

# %%
plt.figure(figsize=(12, 8))
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((1, 2, i)), fontsize=18, ha='center')

# %%
fig = plt.figure(figsize=(12, 8))

fig.subplots_adjust(hspace=0.8, wspace=0.8)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((1, 2, i)), fontsize=18, ha='center')

# %%
nrows = 2
ncols = 3
fig, axes = plt.subplots(nrows=nrows, ncols=ncols)
fig.set_size_inches(12, 8)
for i in range(nrows): 
    for j in range(ncols):
        axes[i, j].text(0.5, 0.5, str((i, j)), fontsize=18, ha='center')

# %%
grid = plt.GridSpec(2, 3, wspace=0.3, hspace=0.3)

# %%
plt.figure(figsize=(12, 8))
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = df['sepal_length']
y = df['sepal_width']

# %%
1-10
bins = 5

# %%
bins1 = 1-2
bins2 = 2-4
bins2 = 4-6

# %%
plt.hist(x, 40)
# Out:
# (array([ 1.,  3.,  1.,  4.,  2.,  5.,  6., 10.,  9.,  0.,  4.,  1.,  6.,
#          7.,  6.,  8.,  7.,  3.,  6.,  0.,  6.,  4.,  9.,  7.,  5.,  2.,
#          8.,  3.,  4.,  0.,  1.,  1.,  3.,  1.,  1.,  0.,  1.,  4.,  0.,
#          1.]),
#  array([4.3 , 4.39, 4.48, 4.57, 4.66, 4.75, 4.84, 4.93, 5.02, 5.11, 5.2 ,
#         5.29, 5.38, 5.47, 5.56, 5.65, 5.74, 5.83, 5.92, 6.01, 6.1 , 6.19,
#         6.28, 6.37, 6.46, 6.55, 6.64, 6.73, 6.82, 6.91, 7.  , 7.09, 7.18,
#         7.27, 7.36, 7.45, 7.54, 7.63, 7.72, 7.81, 7.9 ]),
#  <a list of 40 Patch objects>)

# %%
fig = plt.figure(figsize=(12, 8))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:3,  :3], yticklabels=[], xticklabels=[])
x_axis = fig.add_subplot(grid[3, :-1])
y_axis = fig.add_subplot(grid[:-1, 3])

# data untuk main axis
main_ax.plot(x, y, 'X', markersize=3)
x_axis.hist(x, 40)
y_axis.hist(y, 40, orientation='horizontal')
x_axis.set_title('Test')
x_axis.invert_yaxis();

# %%
plt.figure(figsize=(12, 8))
plt.subplots(4, 4);

# %%
grid[:3,  :3]

# %%
grid[3, :3]
