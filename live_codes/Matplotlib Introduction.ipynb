# %% [markdown]
# - Setting Styles
# - Component Matplotlib
#     - Figures
#     - Axes
#     - Artist
# - Make Plot
# - Save Figure
# - Display Figure

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure()

# %%
plt.figure(figsize=())

# %%
y = [1, 3, 5, 7 ,9]
x = [1, 2, 3, 4, 5]

fig = plt.figure(figsize=(10, 5))

ax2 = fig.add_axes([0, 0, 1, 1])
ax2.bar(x, y)

fig.show();
# Out:
# d:\fauzan\project\cad-it-diagnostic\machine_learning\venv\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if __name__ == '__main__':

# %%
fig = plt.figure()

ax = fig.add_subplot()

ax.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 10, 0.1)
y1 = 0.05 * x**2
y2 = -1 *y1

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')

ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')
ax2.set_ylabel('Y2 data', color='b')
# Out:
# Text(0, 0.5, 'Y2 data')

# %%
# !dir
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is B297-87AF
#
#  Directory of D:\Fauzan\Project\cad-it-diagnostic\machine_learning\code\notebook
#
# 12/10/2020  20:37    <DIR>          .
# 12/10/2020  20:37    <DIR>          ..
# 12/10/2020  19:03    <DIR>          .ipynb_checkpoints
# 12/10/2020  19:03    <DIR>          10092020 145026
# 09/10/2020  15:06    <DIR>          10092020 150335
# 02/10/2020  09:00            24.550 Advance Keras.ipynb
# 12/09/2020  22:10            45.595 AutoSuggestion 1.ipynb
# 12/09/2020  08:14           190.312 AutoSuggestion 2.ipynb
# 09/10/2020  11:03           504.929 Build KNN Model.ipynb
# 09/10/2020  11:03           289.385 Build Model Autosuggest.ipynb
# 06/10/2020  14:06             7.926 C3_W4_lecture_notebook_accuracy.ipynb
# 06/10/2020  14:01            14.336 C3_W4_Lecture_Notebook_Modified_Triplet_Loss.ipynb
# 06/10/2020  14:07            10.184 C3_W4_lecture_notebook_siamese.ipynb
# 10/09/2020  13:03             1.285 config.py
# 09/10/2020  11:03         3.039.418 Dataset Autosuggest.ipynb
# 09/10/2020  13:37    <DIR>          diagnostic
# 09/10/2020  11:03           131.891 Diagnostic Search Engine.ipynb
# 04/08/2020  17:19           146.586 encoder-decoder.ipynb
# 11/09/2020  14:33            59.511 faster-semantic-search-using-faiss.ipynb
# 10/09/2020  11:04           223.848 FastText Mazda + Okuma Dataset.ipynb
# 17/09/2020  00:42            29.909 Indexing Semantic Search.ipynb
# 12/10/2020  20:35           105.405 Matplotlib Introduction.ipynb
# 10/09/2020  11:04            18.307 Predict Model FastText to Mazda Data.ipynb
# 10/09/2020  11:04            36.171 Predict Model FastText to Okuma Data.ipynb
# 17/09/2020  15:22            26.037 Predict_With_KNN_index.ipynb
# 10/09/2020  11:04         1.006.364 Pretrained Model Spacy on Mazda.ipynb
# 12/09/2020  07:52           737.314 Pretrained Model Spacy on Okuma.ipynb
# 09/10/2020  09:35           428.944 processed_training_semantic_search.csv
# 09/10/2020  13:33           434.110 processed_training_semantic_search2.csv
# 03/09/2020  11:41                 0 README.md
# 09/10/2020  08:06    <DIR>          sbert_training4
# 09/10/2020  09:07    <DIR>          sbert_training5
# 09/10/2020  09:42    <DIR>          sbert_training6
# 09/10/2020  10:01    <DIR>          sbert_training7
# 09/10/2020  10:13    <DIR>          sbert_training8
# 12/10/2020  16:25            77.220 Semantic Search 2.ipynb
# 10/09/2020  11:04             9.900 Semantic Search ELMO Model.ipynb
# 10/09/2020  11:04            53.467 Semantic Search FastText Model with Mazda Data.ipynb
# 10/09/2020  11:04           689.975 Semantic Search with Universal Sentence Encoder lite.ipynb
# 17/09/2020  00:42        11.227.847 Semantic Search with Universal Sentence Encoder.ipynb
# 12/10/2020  16:23           234.886 Sentence Transformer.ipynb
# 09/10/2020  11:03             6.490 SpellChecker.ipynb
# 12/10/2020  14:00            57.660 Tensorflow.ipynb
# 12/10/2020  20:37            25.286 test.png
# 09/10/2020  11:03            88.908 Untitled.ipynb
# 09/10/2020  11:03             5.015 Untitled1.ipynb
# 08/10/2020  13:24             1.005 Untitled2.ipynb
# 12/10/2020  16:33           196.573 Untitled3.ipynb
# 10/09/2020  11:04    <DIR>          utils
# 10/09/2020  11:04         2.944.934 WordColus Diagnostic.ipynb
# 16/09/2020  21:26    <DIR>          __pycache__
#               38 File(s)     23.131.483 bytes
#               13 Dir(s)  460.448.313.344 bytes free

# %%
from IPython.display import Image

# %%
Image('test.png')

# %%
0 - 1

# %%
y = [1, 3, 5, 7 ,9]
x = [1, 2, 3, 4, 5]

plt.plot(x, y)
plt.show()

# %%
plt.style.use('fivethirtyeight')
